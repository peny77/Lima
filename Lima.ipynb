# %% [markdown]
# # **Nutrition Facts for McDonalds**

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('menu.csv')
df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# 0                             25        0.0  ...             31
# 1                             15        0.0  ...             30
# 2                             42        0.0  ...             29
# 3                             52        0.0  ...             30
# 4                             42        0.0  ...             30
#
#    Carbohydrates (% Daily Value)  Dietary Fiber  \
# 0                             10              4
# 1                             10              4
# 2                             10              4
# 3                             10              4
# 4                             10              4
#
#    Dietary Fiber (% Daily Value)  Sugars  Protein  Vitamin A (% Daily Value)  \
# 0                             17       3       17                         10
# 1                             17       3       18                          6
# 2                             17       2       14                          8
# 3                             17       2       21                         15
# 4                             17       2       21                          6
#
#    Vitamin C (% Daily Value)  Calcium (% Daily Value)  Iron (% Daily Value)
# 0                          0                       25                    15
# 1                          0                       25                     8
# 2                          0                       25                    10
# 3                          0                       30                    15
# 4                          0                       25                    10
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Diskripsi Data

# %%
df.describe() #include='all'
# Out:
#           Calories  Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count   260.000000         260.000000  260.000000                 260.000000
# mean    368.269231         127.096154   14.165385                  21.815385
# std     240.269886         127.875914   14.205998                  21.885199
# min       0.000000           0.000000    0.000000                   0.000000
# 25%     210.000000          20.000000    2.375000                   3.750000
# 50%     340.000000         100.000000   11.000000                  17.000000
# 75%     500.000000         200.000000   22.250000                  35.000000
# max    1880.000000        1060.000000  118.000000                 182.000000
#
#        Saturated Fat  Saturated Fat (% Daily Value)   Trans Fat  Cholesterol  \
# count     260.000000                     260.000000  260.000000   260.000000
# mean        6.007692                      29.965385    0.203846    54.942308
# std         5.321873                      26.639209    0.429133    87.269257
# min         0.000000                       0.000000    0.000000     0.000000
# 25%         1.000000                       4.750000    0.000000     5.000000
# 50%         5.000000                      24.000000    0.000000    35.000000
# 75%        10.000000                      48.000000    0.000000    65.000000
# max        20.000000                     102.000000    2.500000   575.000000
#
#        Cholesterol (% Daily Value)       Sodium  ...  Carbohydrates  \
# count                   260.000000   260.000000  ...     260.000000
# mean                     18.392308   495.750000  ...      47.346154
# std                      29.091653   577.026323  ...      28.252232
# min                       0.000000     0.000000  ...       0.000000
# 25%                       2.000000   107.500000  ...      30.000000
# 50%                      11.000000   190.000000  ...      44.000000
# 75%                      21.250000   865.000000  ...      60.000000
# max                     192.000000  3600.000000  ...     141.000000
#
#        Carbohydrates (% Daily Value)  Dietary Fiber  \
# count                     260.000000     260.000000
# mean                       15.780769       1.630769
# std                         9.419544       1.567717
# min                         0.000000       0.000000
# 25%                        10.000000       0.000000
# 50%                        15.000000       1.000000
# 75%                        20.000000       3.000000
# max                        47.000000       7.000000
#
#        Dietary Fiber (% Daily Value)      Sugars     Protein  \
# count                     260.000000  260.000000  260.000000
# mean                        6.530769   29.423077   13.338462
# std                         6.307057   28.679797   11.426146
# min                         0.000000    0.000000    0.000000
# 25%                         0.000000    5.750000    4.000000
# 50%                         5.000000   17.500000   12.000000
# 75%                        10.000000   48.000000   19.000000
# max                        28.000000  128.000000   87.000000
#
#        Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# count                 260.000000                 260.000000
# mean                   13.426923                   8.534615
# std                    24.366381                  26.345542
# min                     0.000000                   0.000000
# 25%                     2.000000                   0.000000
# 50%                     8.000000                   0.000000
# 75%                    15.000000                   4.000000
# max                   170.000000                 240.000000
#
#        Calcium (% Daily Value)  Iron (% Daily Value)
# count               260.000000            260.000000
# mean                 20.973077              7.734615
# std                  17.019953              8.723263
# min                   0.000000              0.000000
# 25%                   6.000000              0.000000
# 50%                  20.000000              4.000000
# 75%                  30.000000             15.000000
# max                  70.000000             40.000000
#
# [8 rows x 21 columns]

# %% [markdown]
# #### Nama Kolom

# %%
df.columns
# Out:
# Index(['Category', 'Item', 'Serving Size', 'Calories', 'Calories from Fat',
#        'Total Fat', 'Total Fat (% Daily Value)', 'Saturated Fat',
#        'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#        'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#        'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)'],
#       dtype='object')

# %% [markdown]
# #### Cek Data

# %% [markdown]
# > Mengecek data ataukah ada yang null

# %%
print(df.isnull().any())
# Out:
# Category                         False
# Item                             False
# Serving Size                     False
# Calories                         False
# Calories from Fat                False
# Total Fat                        False
# Total Fat (% Daily Value)        False
# Saturated Fat                    False
# Saturated Fat (% Daily Value)    False
# Trans Fat                        False
# Cholesterol                      False
# Cholesterol (% Daily Value)      False
# Sodium                           False
# Sodium (% Daily Value)           False
# Carbohydrates                    False
# Carbohydrates (% Daily Value)    False
# Dietary Fiber                    False
# Dietary Fiber (% Daily Value)    False
# Sugars                           False
# Protein                          False
# Vitamin A (% Daily Value)        False
# Vitamin C (% Daily Value)        False
# Calcium (% Daily Value)          False
# Iron (% Daily Value)             False
# dtype: bool

# %% [markdown]
# > Mengecek ukuran data

# %%
df.shape
# Out:
# (260, 24)

# %% [markdown]
# ## Kategori

# %% [markdown]
# > Menampilkan data berdasarkan kategori

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(font_scale=2)
plt.figure(figsize=(8, 5))
sns.countplot(y='Category', data=df, label="Count")

# %% [markdown]
# ## a) How many calories does the average McDonald's value meal contain?

# %% [markdown]
# > Berapa rata² Kalori yang terkandung dalam menu² makanan McDonald?*Solusi:* cari rata² kalori tiap kategori, visualisasi dengan Bar chart

# %%
f, ax = plt.subplots(1, 2, figsize=(25, 15))
mean_kalori = {}
mean_kolesterol = {}

# Rata-rata Kalori
for category in df['Category'].unique():
    mean = int(df[df['Category'] == category]['Calories'].mean())
    mean_kalori[category] = mean
pd.Series(mean_kalori).sort_values(ascending=False).plot.barh(width=0.8, color=sns.color_palette('winter',10), ax=ax[0])
ax[0].set_title("Mean Calories of Different Categories")

# Rata-rata Kolesterol
for category in df['Category'].unique():
    mean = int(df[df['Category'] == category]['Cholesterol'].mean())
    mean_kolesterol[category] = mean
pd.Series(mean_kolesterol).sort_values(ascending=False).plot.barh(width=0.8, color=sns.color_palette('winter',10), ax=ax[1])
ax[1].set_title("Mean Cholesterol of Different Categories");

# %%
f, ax = plt.subplots(1, 2, figsize=(25, 15))
mean_sodium = {}
mean_carbohydrates = {}
mean_sugars = {}
mean_protein = {}

# Rata-rata Sodium
for category in df['Category'].unique():
    mean = int(df[df['Category'] == category]['Sodium'].mean())
    mean_sodium[category] = mean
pd.Series(mean_sodium).sort_values(ascending=False).plot.barh(width=0.8, color=sns.color_palette('winter',10), ax=ax[0])
ax[0].set_title("Mean Sodium of Different Categories")

# Rata-rata Carbohydrates
for category in df['Category'].unique():
    mean = int(df[df['Category'] == category]['Carbohydrates'].mean())
    mean_carbohydrates[category] = mean
pd.Series(mean_carbohydrates).sort_values(ascending=False).plot.barh(width=0.8, color=sns.color_palette('winter',10), ax=ax[1])
ax[1].set_title("Mean Carbohydrates of Different Categories");

# %%
f, ax = plt.subplots(1, 2, figsize=(25, 15))
mean_sugars = {}
mean_protein = {}

# Rata-rata Sugars
for category in df['Category'].unique():
    mean = int(df[df['Category'] == category]['Sugars'].mean())
    mean_sugars[category] = mean
pd.Series(mean_sugars).sort_values(ascending=False).plot.barh(width=0.8, color=sns.color_palette('winter',10), ax=ax[0])
ax[0].set_title("Mean Sugars of Different Categories")

# Rata-rata Protein
for category in df['Category'].unique():
    mean = int(df[df['Category'] == category]['Protein'].mean())
    mean_protein[category] = mean
pd.Series(mean_protein).sort_values(ascending=False).plot.barh(width=0.8, color=sns.color_palette('winter',10), ax=ax[1])
ax[1].set_title("Mean Protein of Different Categories");

# %% [markdown]
# ## b) How much do beverages, like soda or coffee, contribute to the overall caloric intake?

# %% [markdown]
# > Seberapa banyak minuman seperti soda/kopi berkontribusi pada asupan kalori secara keseluruhan?<br>*Solusi:* Cari rata² kalori dari beberapa kategori Minuman (Beverage), lalu hitung berapa persen kalori yang disumbangkan untuk memenuhi kebutuhan kalori manusia per harinya. Karena laki² dan wanita berbeda jumlah kebutuhan kalorinya jadi persenannya dihitung masing². Visualisasi bisa pakai bar chart bertumpuk

# %% [markdown]
# ### Mean Beverages

# %%
beverage_mean = df[df.Category == 'Beverages'].mean()
beverage_mean.head()
# Out:
# Calories                     113.703704
# Calories from Fat              0.740741
# Total Fat                      0.092593
# Total Fat (% Daily Value)      0.148148
# Saturated Fat                  0.055556
# dtype: float64

# %%
beverage = df[df.Category == 'Beverages']
beverage.head()
# Out:
#       Category                        Item  Serving Size  Calories  \
# 110  Beverages   Coca-Cola Classic (Small)  16 fl oz cup       140
# 111  Beverages  Coca-Cola Classic (Medium)  21 fl oz cup       200
# 112  Beverages   Coca-Cola Classic (Large)  30 fl oz cup       280
# 113  Beverages   Coca-Cola Classic (Child)  12 fl oz cup       100
# 114  Beverages           Diet Coke (Small)  16 fl oz cup         0
#
#      Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 110                  0        0.0                          0            0.0
# 111                  0        0.0                          0            0.0
# 112                  0        0.0                          0            0.0
# 113                  0        0.0                          0            0.0
# 114                  0        0.0                          0            0.0
#
#      Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# 110                              0        0.0  ...             39
# 111                              0        0.0  ...             55
# 112                              0        0.0  ...             76
# 113                              0        0.0  ...             28
# 114                              0        0.0  ...              0
#
#      Carbohydrates (% Daily Value)  Dietary Fiber  \
# 110                             13              0
# 111                             18              0
# 112                             25              0
# 113                              9              0
# 114                              0              0
#
#      Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 110                              0      39        0
# 111                              0      55        0
# 112                              0      76        0
# 113                              0      28        0
# 114                              0       0        0
#
#      Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 110                          0                          0
# 111                          0                          0
# 112                          0                          0
# 113                          0                          0
# 114                          0                          0
#
#      Calcium (% Daily Value)  Iron (% Daily Value)
# 110                        0                     0
# 111                        0                     0
# 112                        0                     0
# 113                        0                     0
# 114                        0                     0
#
# [5 rows x 24 columns]

# %% [markdown]
# ## c) Does ordered grilled chicken instead of crispy increase a sandwich's nutritional value?

# %% [markdown]
# > Apakah dengan memesan grilled chicken daripada crispy chicken akan meningkatkan nilai gizi (niutrisi) dari sandwich?*Solusi:* hitung rata² kalori dari sandwich dg grilled chicken dan sandwich dg crispy chicken, kemudian bandingkan. Visualisasi dengan Bar chart

# %% [markdown]
# ### Mean Chicken & Fish

# %%
chickenfish_mean = df[df.Category == 'Chicken & Fish'].mean()
chickenfish_mean.head()
# Out:
# Calories                     552.962963
# Calories from Fat            242.222222
# Total Fat                     26.962963
# Total Fat (% Daily Value)     41.333333
# Saturated Fat                  6.166667
# dtype: float64

# %%
chickenfish = df[df.Category == 'Chicken & Fish']
chickenfish.head()
# Out:
#           Category                                       Item    Serving Size  \
# 57  Chicken & Fish    Premium Crispy Chicken Classic Sandwich  7.5 oz (213 g)
# 58  Chicken & Fish   Premium Grilled Chicken Classic Sandwich    7 oz (200 g)
# 59  Chicken & Fish       Premium Crispy Chicken Club Sandwich  8.8 oz (249 g)
# 60  Chicken & Fish      Premium Grilled Chicken Club Sandwich  8.3 oz (235 g)
# 61  Chicken & Fish  Premium Crispy Chicken Ranch BLT Sandwich  8.1 oz (230 g)
#
#     Calories  Calories from Fat  Total Fat  Total Fat (% Daily Value)  \
# 57       510                200       22.0                         33
# 58       350                 80        9.0                         13
# 59       670                300       33.0                         51
# 60       510                180       20.0                         31
# 61       610                250       28.0                         43
#
#     Saturated Fat  Saturated Fat (% Daily Value)  Trans Fat  ...  \
# 57            3.5                             18        0.0  ...
# 58            2.0                              9        0.0  ...
# 59            9.0                             44        0.0  ...
# 60            7.0                             36        0.0  ...
# 61            6.0                             31        0.0  ...
#
#     Carbohydrates  Carbohydrates (% Daily Value)  Dietary Fiber  \
# 57             55                             18              3
# 58             42                             14              3
# 59             58                             19              3
# 60             44                             15              3
# 61             57                             19              3
#
#     Dietary Fiber (% Daily Value)  Sugars  Protein  Vitamin A (% Daily Value)  \
# 57                             13      10       24                          4
# 58                             13       8       28                          4
# 59                             14      11       36                          8
# 60                             13       9       40                          8
# 61                             13      11       32                          4
#
#     Vitamin C (% Daily Value)  Calcium (% Daily Value)  Iron (% Daily Value)
# 57                          6                       15                    20
# 58                          8                       15                    20
# 59                         20                       30                    20
# 60                         20                       30                    20
# 61                         20                       15                    20
#
# [5 rows x 24 columns]

# %% [markdown]
# ## d) What about ordering egg whites instead of whole eggs?

# %% [markdown]
# > Lalu bagaimana jika memesan Egg white daripada Whole Egg?*Solusi:* sama seperti kasus c. Hitung rata² kalori dari menu makanan yang mengandung Egg white dan Whole Egg dari kategori Breakfast, kemudian bandingkan. Visualisasi dg Bar Chart

# %% [markdown]
# ### Mean Breakfast

# %%
breakfast_mean = df[df.Category == 'Breakfast'].mean()
breakfast_mean.head()
# Out:
# Calories                     526.666667
# Calories from Fat            248.928571
# Total Fat                     27.690476
# Total Fat (% Daily Value)     42.666667
# Saturated Fat                 10.654762
# dtype: float64

# %%
breakfast = df[df.Category == 'Breakfast']
breakfast.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# 0                             25        0.0  ...             31
# 1                             15        0.0  ...             30
# 2                             42        0.0  ...             29
# 3                             52        0.0  ...             30
# 4                             42        0.0  ...             30
#
#    Carbohydrates (% Daily Value)  Dietary Fiber  \
# 0                             10              4
# 1                             10              4
# 2                             10              4
# 3                             10              4
# 4                             10              4
#
#    Dietary Fiber (% Daily Value)  Sugars  Protein  Vitamin A (% Daily Value)  \
# 0                             17       3       17                         10
# 1                             17       3       18                          6
# 2                             17       2       14                          8
# 3                             17       2       21                         15
# 4                             17       2       21                          6
#
#    Vitamin C (% Daily Value)  Calcium (% Daily Value)  Iron (% Daily Value)
# 0                          0                       25                    15
# 1                          0                       25                     8
# 2                          0                       25                    10
# 3                          0                       30                    15
# 4                          0                       25                    10
#
# [5 rows x 24 columns]

# %% [markdown]
# ## e) What is the least number of items could you order from the menu to meet one day's nutritional requirements?

# %% [markdown]
# > Berapa jumlah makanan paling sedikit yang dapat dipesan dari menu u/ memenuhi kebutuhan nutrisi dalam 1 hari?*Solusi:* Cari rata² kalori per kategori kemudian kombinasikan menu dari tiap kategori yang nantinya jika dijumlahkan bisa memenuhi asupan kalori rata2 manusia per hari. Mungkin ini pakai conditional if dan looping juga untuk bisa dapat kombinasinya. Atau ada yang punya ide lain?
